# %%
import pandas as pd

# %% [markdown]
# # Consulta 1

# %%
steam_games = pd.read_csv('../data/limpio/steam_games.csv.gz',compression='gzip')
users_items = pd.read_csv('../data/limpio/users_items.csv.gz',compression='gzip')

# %%
steam_games.head(3)
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro  ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...
# 1  Making Fun, Inc.  ['Free to Play', 'Strategy', 'Indie', 'RPG', '...
# 2      Poolians.com  ['Free to Play', 'Simulation', 'Sports', 'Casu...
#
#                   app_name release_date         price     id  \
# 0      Lost Summoner Kitty   2018-01-04          4.99 761140
# 1                Ironbound   2018-01-04  Free To Play 643980
# 2  Real Pool 3D - Poolians   2017-07-24  Free to Play 670290
#
#           developer  year
# 0         Kotoshiro  2018
# 1  Secret Level SRL  2018
# 2      Poolians.com  2017

# %%
users_items.head(3)
# Out:
#              user_id  item_id  playtime_forever  playtime_2weeks
# 0  76561197970982479       10                 0                0
# 1  76561197970982479       20                 0                0
# 2  76561197970982479       30                 0                0

# %%
steam_games=steam_games[['genres', 'id','year']]
users_items=users_items[['item_id','playtime_forever']]

# %%
consulta_1 = steam_games.merge(users_items,left_on='id', right_on= 'item_id',how='inner')

# %%
consulta_1.drop(columns=['id','item_id'], inplace=True)

# %%
consulta_1
# Out:
#                                                     genres  year  \
# 0        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 1        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 2        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 3        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 4        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# ...                                                    ...   ...
# 4215459  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215460  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215461  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215462  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215463  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
#
#          playtime_forever
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 4215459                 0
# 4215460                 0
# 4215461                 0
# 4215462                 0
# 4215463                 2
#
# [4215464 rows x 3 columns]

# %%
consulta_1 = consulta_1.groupby(['year','genres']).sum().reset_index()

# %%
consulta_1
# Out:
#       year                                             genres  \
# 0     1983  ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...
# 1     1984  ['Adventure', 'Casual', 'Action', 'Quick-Time ...
# 2     1987  ['Adventure', 'Classic', 'Pixel Graphics', 'Po...
# 3     1987  ['Adventure', 'Simulation', 'Pirates', 'Classic']
# 4     1987                            ['Simulation', 'Retro']
# ...    ...                                                ...
# 8166  2017  ['Visual Novel', 'Anime', 'Indie', 'Adventure'...
# 8167  2018  ['Early Access', 'Action', 'Adventure', 'RPG',...
# 8168  2018  ['Early Access', 'Action', 'Indie', 'Simulation']
# 8169  2018  ['Early Access', 'Indie', 'Platformer', 'Metro...
# 8170  2018                            ['Early Access', 'RPG']
#
#       playtime_forever
# 0                   60
# 1                    6
# 2                  125
# 3                    4
# 4                    0
# ...                ...
# 8166               157
# 8167                 0
# 8168                37
# 8169                 2
# 8170                63
#
# [8171 rows x 3 columns]

# %%
consulta_1.to_csv('../data/consultas/PlayTimeGenre.csv')

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
consulta_1[consulta_1['genres'].str.contains('Early Access')][['year','playtime_forever']].groupby('year').sum()
# Out:
#       playtime_forever
# year
# 2012             54176
# 2013           2006105
# 2014            189978
# 2015            228858
# 2016            165136
# 2017               574
# 2018               102

# %%
consulta_1[consulta_1['genres'].str.contains('RPG')][['year','playtime_forever']].groupby('year').sum()
# Out:
#       playtime_forever
# year
# 1988               233
# 1989                 1
# 1991                 0
# 1992                36
# 1993                 2
# 1994                35
# 1995                86
# 1996               425
# 1997              6113
# 1998              6615
# 1999              5547
# 2000             10686
# 2001              3610
# 2002             31189
# 2003            173699
# 2004             18037
# 2005            108616
# 2006             40585
# 2007            181485
# 2008            267177
# 2009            691653
# 2010           1685624
# 2011           4560611
# 2012           4743078
# 2013           3460044
# 2014           1934987
# 2015           4189954
# 2016           1319097
# 2017           1146988
# 2018                64

# %%
def PlayTimeGenre(genero: str):
  
  try:
    consulta_1 = pd.read_csv('../data/consultas/PlayTimeGenre.csv')
    year_max =consulta_1[consulta_1['genres'].str.contains(genero)][['year','playtime_forever']].groupby('year').sum().idxmax().iloc[0]
    return year_max
  
  except Exception as e :
    return {f'ERROR: {e}'}

# %%
PlayTimeGenre('Early Access')
# Out:
# 2013

# %%
PlayTimeGenre('Action')
# Out:
# 2012

# %%
PlayTimeGenre('algo que NO existe')
# Out:
# {'ERROR: attempt to get argmax of an empty sequence'}

# %% [markdown]
# # Consulta 2

# %%
steam_games = pd.read_csv('../data/limpio/steam_games.csv.gz',compression='gzip')
users_items = pd.read_csv('../data/limpio/users_items.csv.gz',compression='gzip')

# %%
steam_games.head(3)
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro  ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...
# 1  Making Fun, Inc.  ['Free to Play', 'Strategy', 'Indie', 'RPG', '...
# 2      Poolians.com  ['Free to Play', 'Simulation', 'Sports', 'Casu...
#
#                   app_name release_date         price     id  \
# 0      Lost Summoner Kitty   2018-01-04          4.99 761140
# 1                Ironbound   2018-01-04  Free To Play 643980
# 2  Real Pool 3D - Poolians   2017-07-24  Free to Play 670290
#
#           developer  year
# 0         Kotoshiro  2018
# 1  Secret Level SRL  2018
# 2      Poolians.com  2017

# %%
users_items.head(3)
# Out:
#              user_id  item_id  playtime_forever  playtime_2weeks
# 0  76561197970982479       10                 0                0
# 1  76561197970982479       20                 0                0
# 2  76561197970982479       30                 0                0

# %%
steam_games=steam_games[['genres', 'id','year']]
users_items=users_items[['item_id','playtime_forever','user_id']]

# %%
consulta_2 = steam_games.merge(users_items,left_on='id', right_on= 'item_id',how='inner')

# %%
consulta_2.drop(columns=['id','item_id'], inplace=True)

# %%
consulta_2
# Out:
#                                                     genres  year  \
# 0        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 1        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 2        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 3        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# 4        ['Racing', 'Action', 'Classic', 'Indie', 'Gore...  1997
# ...                                                    ...   ...
# 4215459  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215460  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215461  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215462  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
# 4215463  ['Action', 'FPS', 'Shooter', 'Multiplayer', 'S...  2004
#
#          playtime_forever                user_id
# 0                       0               UTNerd24
# 1                       0  I_DID_911_JUST_SAYING
# 2                       0      76561197962104795
# 3                       0               r3ap3r78
# 4                       0               saint556
# ...                   ...                    ...
# 4215459                 0      76561198273508956
# 4215460                 0      76561198282090798
# 4215461                 0                 943525
# 4215462                 0      76561198283312749
# 4215463                 2      76561198312638244
#
# [4215464 rows x 4 columns]

# %%
consulta_2=consulta_2.groupby(['year','user_id']).sum().reset_index()

# %%
consulta_2
# Out:
#         year            user_id  \
# 0       1983               2Ta4
# 1       1983  76561197960324641
# 2       1983  76561197966936422
# 3       1983  76561197968887720
# 4       1983  76561197969020980
# ...      ...                ...
# 772332  2018           xerector
# 772333  2018              xinyo
# 772334  2018           xmatiias
# 772335  2018           yes12429
# 772336  2018            yukiist
#
#                                                    genres  playtime_forever
# 0       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 0
# 1       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 0
# 2       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 6
# 3       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 0
# 4       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 2
# ...                                                   ...               ...
# 772332  ['Early Access', 'Indie', 'Platformer', 'Metro...                 0
# 772333  ['Early Access', 'Action', 'Indie', 'Simulatio...                 0
# 772334  ['Early Access', 'Action', 'Adventure', 'RPG',...                 0
# 772335  ['Early Access', 'Indie', 'Platformer', 'Metro...                 0
# 772336  ['Early Access', 'Indie', 'Platformer', 'Metro...                 0
#
# [772337 rows x 4 columns]

# %%
consulta_2.to_csv('../data/consultas/UserForGenre.csv')

# %%
consulta_2
# Out:
#         year            user_id  \
# 0       1983               2Ta4
# 1       1983  76561197960324641
# 2       1983  76561197966936422
# 3       1983  76561197968887720
# 4       1983  76561197969020980
# ...      ...                ...
# 772332  2018           xerector
# 772333  2018              xinyo
# 772334  2018           xmatiias
# 772335  2018           yes12429
# 772336  2018            yukiist
#
#                                                    genres  playtime_forever
# 0       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 0
# 1       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 0
# 2       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 6
# 3       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 0
# 4       ['Adventure', 'Action', 'FMV', 'Casual', 'Quic...                 2
# ...                                                   ...               ...
# 772332  ['Early Access', 'Indie', 'Platformer', 'Metro...                 0
# 772333  ['Early Access', 'Action', 'Indie', 'Simulatio...                 0
# 772334  ['Early Access', 'Action', 'Adventure', 'RPG',...                 0
# 772335  ['Early Access', 'Indie', 'Platformer', 'Metro...                 0
# 772336  ['Early Access', 'Indie', 'Platformer', 'Metro...                 0
#
# [772337 rows x 4 columns]

# %%
usuario=consulta_2[consulta_2['genres'].str.contains('Action')].sort_values('playtime_forever', ascending=False).iloc[0,1]

# %%
usuario
# Out:
# 'REBAS_AS_F-T'

# %%
tabla=consulta_2[['year','playtime_forever']][consulta_2['user_id']==usuario]

# %%
tabla
# Out:
#         year  playtime_forever
# 17230   1996                 0
# 36769   1998                 0
# 50550   1999                 4
# 65439   2000                 0
# 80322   2001                 0
# 93829   2002                 0
# 112207  2003                31
# 143024  2004               152
# 174683  2005                55
# 220211  2006                31
# 256605  2007               174
# 289990  2008                84
# 335231  2009              1029
# 383741  2010              1216
# 437921  2011              3146
# 497509  2012              4459
# 554484  2013              6723
# 609522  2014              7975
# 662709  2015             17833
# 710913  2016             21983
# 758464  2017               584

# %%
consulta_2[['year','playtime_forever']][(consulta_2['user_id']==usuario) & (consulta_2['genres'].str.contains('Action'))]
# Out:
#         year  playtime_forever
# 17230   1996                 0
# 36769   1998                 0
# 50550   1999                 4
# 65439   2000                 0
# 80322   2001                 0
# 93829   2002                 0
# 112207  2003                31
# 143024  2004               152
# 174683  2005                55
# 220211  2006                31
# 256605  2007               174
# 289990  2008                84
# 335231  2009              1029
# 383741  2010              1216
# 437921  2011              3146
# 497509  2012              4459
# 554484  2013              6723
# 609522  2014              7975
# 662709  2015             17833
# 710913  2016             21983
# 758464  2017               584

# %%
consulta_2[consulta_2['user_id']=='REBAS_AS_F-T']
# Out:
#         year       user_id                                             genres  \
# 17230   1996  REBAS_AS_F-T         ['Action', 'Free to Play', "Shoot 'Em Up"]
# 36769   1998  REBAS_AS_F-T  ['FPS', 'Classic', 'Action', 'Sci-fi', 'Single...
# 50550   1999  REBAS_AS_F-T  ['Action', 'Classic', 'Open World', 'Singlepla...
# 65439   2000  REBAS_AS_F-T  ['Simulation', 'Strategy', 'Space', 'Sci-fi', ...
# 80322   2001  REBAS_AS_F-T  ['Free to Play', 'Action', 'Indie', 'Multiplay...
# 93829   2002  REBAS_AS_F-T  ['RPG', 'First-Person', 'Classic', 'Atmospheri...
# 112207  2003  REBAS_AS_F-T  ['Racing', 'Open World', 'Great Soundtrack', '...
# 143024  2004  REBAS_AS_F-T  ['FPS', 'Action', 'Classic', 'Shooter', 'Open ...
# 174683  2005  REBAS_AS_F-T  ['Open World', 'Action', 'Multiplayer', 'Crime...
# 220211  2006  REBAS_AS_F-T  ['Sandbox', 'Multiplayer', 'Funny', 'Moddable'...
# 256605  2007  REBAS_AS_F-T  ['Action', 'Adventure', 'Third-Person Shooter'...
# 289990  2008  REBAS_AS_F-T  ['Casual']['Action', 'Indie', 'Tanks', 'Single...
# 335231  2009  REBAS_AS_F-T  ['Open World', 'Action', 'Sandbox', 'Character...
# 383741  2010  REBAS_AS_F-T  ['Free to Play', 'Action', 'Multiplayer', 'Pir...
# 437921  2011  REBAS_AS_F-T  ['Action', 'Open World', 'Crime', 'Story Rich'...
# 497509  2012  REBAS_AS_F-T  ['Cyberpunk', 'FPS', 'Action', 'Sci-fi', 'Indi...
# 554484  2013  REBAS_AS_F-T  ['Free to Play', 'MMORPG', 'Massively Multipla...
# 609522  2014  REBAS_AS_F-T  ['Action', 'Open World', 'Female Protagonist',...
# 662709  2015  REBAS_AS_F-T  ['Free to Play', 'FPS', 'Action', 'Multiplayer...
# 710913  2016  REBAS_AS_F-T  ['Strategy', 'Free to Play', 'Medieval', 'Mult...
# 758464  2017  REBAS_AS_F-T  ['Strategy', 'Casual', 'Indie', 'Free to Play'...
#
#         playtime_forever
# 17230                  0
# 36769                  0
# 50550                  4
# 65439                  0
# 80322                  0
# 93829                  0
# 112207                31
# 143024               152
# 174683                55
# 220211                31
# 256605               174
# 289990                84
# 335231              1029
# 383741              1216
# 437921              3146
# 497509              4459
# 554484              6723
# 609522              7975
# 662709             17833
# 710913             21983
# 758464               584

# %%
tabla=tabla[tabla['playtime_forever']>0.5]

# %%
tabla
# Out:
#         year  playtime_forever
# 50550   1999                 4
# 112207  2003                31
# 143024  2004               152
# 174683  2005                55
# 220211  2006                31
# 256605  2007               174
# 289990  2008                84
# 335231  2009              1029
# 383741  2010              1216
# 437921  2011              3146
# 497509  2012              4459
# 554484  2013              6723
# 609522  2014              7975
# 662709  2015             17833
# 710913  2016             21983
# 758464  2017               584

# %%
# paso el df a diccionario
dict_data = tabla.to_dict(orient='records')
# aplano el diccionario en una lista
lista = [{'Año': d['year'], 'Horas': int(round(d['playtime_forever'],0))} for d in dict_data]
# formo un diccionario con la lista
#dicc = {'Horas jugadas': lista}
#print(dicc)
gen="Action"
resultado = {"Usuario con más horas jugadas para Género {}".format(gen): usuario,
             "Horas jugadas": lista}
print(resultado)
# Out:
# {'Usuario con más horas jugadas para Género Action': 'REBAS_AS_F-T', 'Horas jugadas': [{'Año': 1999, 'Horas': 4}, {'Año': 2003, 'Horas': 31}, {'Año': 2004, 'Horas': 152}, {'Año': 2005, 'Horas': 55}, {'Año': 2006, 'Horas': 31}, {'Año': 2007, 'Horas': 174}, {'Año': 2008, 'Horas': 84}, {'Año': 2009, 'Horas': 1029}, {'Año': 2010, 'Horas': 1216}, {'Año': 2011, 'Horas': 3146}, {'Año': 2012, 'Horas': 4459}, {'Año': 2013, 'Horas': 6723}, {'Año': 2014, 'Horas': 7975}, {'Año': 2015, 'Horas': 17833}, {'Año': 2016, 'Horas': 21983}, {'Año': 2017, 'Horas': 584}]}

# %%
def UserForGenre(genero: str):
  
  try:
    consulta_2 = pd.read_csv('../data/consultas/UserForGenre.csv')
    usuario=consulta_2[consulta_2['genres'].str.contains(genero)].sort_values('playtime_forever', ascending=False).iloc[0,2]
    consulta_2=consulta_2[['year','playtime_forever']][consulta_2['user_id']==usuario][consulta_2[['year','playtime_forever']][consulta_2['user_id']==usuario]['playtime_forever']>0.5]
    # paso el df a diccionario
    dict_data = consulta_2.to_dict(orient='records')
    # aplano el diccionario en una lista
    lista = [{'Año': d['year'], 'Horas': int(round(d['playtime_forever'],0))} for d in dict_data]
    resultado = {"Usuario con más horas jugadas para Género {}".format(genero): usuario,
                "Horas jugadas": lista}
    return resultado
  
  except Exception as e :
    return {f'ERROR: {e}'}

# %%
UserForGenre('Action')
# Out:
# {'Usuario con más horas jugadas para Género Action': 'REBAS_AS_F-T',
#  'Horas jugadas': [{'Año': 1999, 'Horas': 4},
#   {'Año': 2003, 'Horas': 31},
#   {'Año': 2004, 'Horas': 152},
#   {'Año': 2005, 'Horas': 55},
#   {'Año': 2006, 'Horas': 31},
#   {'Año': 2007, 'Horas': 174},
#   {'Año': 2008, 'Horas': 84},
#   {'Año': 2009, 'Horas': 1029},
#   {'Año': 2010, 'Horas': 1216},
#   {'Año': 2011, 'Horas': 3146},
#   {'Año': 2012, 'Horas': 4459},
#   {'Año': 2013, 'Horas': 6723},
#   {'Año': 2014, 'Horas': 7975},
#   {'Año': 2015, 'Horas': 17833},
#   {'Año': 2016, 'Horas': 21983},
#   {'Año': 2017, 'Horas': 584}]}

# %%
user='REBAS_AS_F-T'

# %%
UserForGenre('Action')
# Out:
# {'Usuario con más horas jugadas para Género Action': 'REBAS_AS_F-T',
#  'Horas jugadas': [{'Año': 1999, 'Horas': 4},
#   {'Año': 2003, 'Horas': 31},
#   {'Año': 2004, 'Horas': 152},
#   {'Año': 2005, 'Horas': 55},
#   {'Año': 2006, 'Horas': 31},
#   {'Año': 2007, 'Horas': 174},
#   {'Año': 2008, 'Horas': 84},
#   {'Año': 2009, 'Horas': 1029},
#   {'Año': 2010, 'Horas': 1216},
#   {'Año': 2011, 'Horas': 3146},
#   {'Año': 2012, 'Horas': 4459},
#   {'Año': 2013, 'Horas': 6723},
#   {'Año': 2014, 'Horas': 7975},
#   {'Año': 2015, 'Horas': 17833},
#   {'Año': 2016, 'Horas': 21983},
#   {'Año': 2017, 'Horas': 584}]}
